# %%
import numpy as np
import pandas as pd

# %%
media = pd.read_csv(r"C:\Users\Ins 5584-1264\Downloads\movies.csv")

# %%
media.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# listed_in        object
# dtype: object

# %%
media['duration'] = media['duration'].astype('|S')

# %%
media.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration          |S146
# listed_in        object
# dtype: object

# %%
media.head()
# Out:
#   show_id     type                  title         director        country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3      s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#   date_added  release_year rating      duration  \
# 0  9/25/2021        2020.0  PG-13     b'90 min'
# 1  9/24/2021        2021.0  TV-MA  b'2 Seasons'
# 2  9/24/2021        2021.0  TV-MA   b'1 Season'
# 3  9/24/2021        2021.0  TV-MA   b'1 Season'
# 4  9/24/2021        2021.0  TV-MA  b'2 Seasons'
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
media.shape
# Out:
# (8809, 10)

# %%
media.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False      True    False       False         False
# 2       False  False  False     False     True       False         False
# 3       False  False  False      True     True       False         False
# 4       False  False  False      True    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8804    False  False  False     False    False       False         False
# 8805    False  False  False      True     True       False         False
# 8806    False  False  False     False    False       False         False
# 8807    False  False  False     False    False       False         False
# 8808    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# ...

# %%
media.isnull().sum().sort_values(ascending = False)
#here we can see that the director column has the most number of null values, followed by country. The other columns have only a few mull values
# Out:
# director        2636
# country          833
# date_added        13
# rating             6
# release_year       3
# listed_in          3
# title              2
# type               1
# show_id            0
# duration           0
# dtype: int64

# %%
media.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show         Blood & Water              NaN   South Africa
#
#   date_added  release_year rating      duration  \
# 0  9/25/2021        2020.0  PG-13     b'90 min'
# 1  9/24/2021        2021.0  TV-MA  b'2 Seasons'
#
#                                          listed_in
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries

# %%
#to know what are the different ratings 
media['rating'].value_counts()
# Out:
# TV-MA                            3207
# TV-14                            2160
# TV-PG                             862
# R                                 799
# PG-13                             490
# TV-Y7                             334
# TV-Y                              307
# PG                                287
# TV-G                              220
# NR                                 80
# G                                  41
# TV-Y7-FV                            6
# UR                                  3
# NC-17                               3
# Classic Movies, Documentaries       1
# 74 min                              1
# 84 min                              1
# 66 min                              1
# Name: rating, dtype: int64

# %%
media['type'].value_counts()
# there are more movies than TV shows listed. The duration is in seasons for the TV Shows and minutes for the movies
# this is useful for future analysis perhaps based on duration
# Out:
# Movie            6131
# TV Show          2676
# William Wyler       1
# Name: type, dtype: int64

# %%
#showing all movies that were made by the United States
media[media['country'].isin(['United States'])]
# Out:
#      show_id     type                 title         director        country  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 9        s10    Movie          The Starling   Theodore Melfi  United States
# 15       s16  TV Show     Dear White People              NaN  United States
# 27       s28    Movie             Grown Ups     Dennis Dugan  United States
# 28       s29    Movie            Dark Skies    Scott Stewart  United States
# ...      ...      ...                   ...              ...            ...
# 8793   s8792    Movie           Young Adult    Jason Reitman  United States
# 8795   s8794    Movie  Yours, Mine and Ours     Raja Gosnell  United States
# 8804   s8803    Movie                Zodiac    David Fincher  United States
# 8806   s8805    Movie            Zombieland  Ruben Fleischer  United States
# 8807   s8806    Movie                  Zoom     Peter Hewitt  United States
#
#       date_added  release_year rating      duration  \
# ...

# %%
#to get a list of only movies 
movies = media[media['type'].isin(['Movie'])]

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8803   s8802  Movie                           Zinzana
# 8804   s8803  Movie                            Zodiac
# 8806   s8805  Movie                        Zombieland
# 8807   s8806  Movie                              Zoom
# 8808   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8803                Majid Al Ansari
# ...

# %%
movies.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration          |S146
# listed_in        object
# dtype: object

# %%
movies.isnull().sum().sort_values(ascending = False)
# Out:
# country         441
# director        189
# rating            3
# date_added        1
# release_year      1
# listed_in         1
# show_id           0
# type              0
# title             0
# duration          0
# dtype: int64

# %%
movies['rating'].value_counts()
# Out:
# TV-MA       2062
# TV-14       1427
# R            797
# TV-PG        539
# PG-13        490
# PG           287
# TV-Y7        139
# TV-Y         131
# TV-G         126
# NR            75
# G             41
# TV-Y7-FV       5
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
#I'd like to filter down to movies that can be watched with the family 
movies[movies['rating'].isin(['G', 'PG-13', 'PG'])]
#I see that I have 818 options
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 9        s10  Movie                      The Starling
# 27       s28  Movie                         Grown Ups
# 28       s29  Movie                        Dark Skies
# ...      ...    ...                               ...
# 8769   s8768  Movie           XXX: State of the Union
# 8778   s8777  Movie                        Yellowbird
# 8784   s8783  Movie                       Yoga Hosers
# 8795   s8794  Movie              Yours, Mine and Ours
# 8807   s8806  Movie                              Zoom
#
#                            director          country  date_added  \
# 0                   Kirsten Johnson    United States   9/25/2021
# 6     Robert Cullen, José Luis Ucha              NaN   9/24/2021
# 9                    Theodore Melfi    United States   9/24/2021
# ...

# %%
movies['duration'] = movies['duration'].astype('string')
#I'd like the duration to be less than 100 minutes
# Out:
# <ipython-input-124-df5f71ad9396>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].astype('string')

# %%
movies.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         string
# listed_in        object
# dtype: object

# %%
movies['duration'] = movies['duration'].str.upper()
# Out:
# <ipython-input-126-5835382d8f96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str.upper()

# %%
movies['duration'] = movies['duration'].str.replace(' MIN', '')
# Out:
# <ipython-input-127-9aa28668bd6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str.replace(' MIN', '')

# %%
movies['duration']
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8803     96
# 8804    158
# 8806     88
# 8807     88
# 8808    111
# Name: duration, Length: 6131, dtype: string

# %%
movies['duration']
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8803     96
# 8804    158
# 8806     88
# 8807     88
# 8808    111
# Name: duration, Length: 6131, dtype: string

# %%
#movies['duration'].fillna(movies['duration'].mean(), inplace = True)
#movies['duration'].fillna(0)
#movies['duration'] = movies['duration'].astype(int)
pd.set_option('display.max_rows', 300)
movies['duration'].head(300)
#not able to move forward
# Out:
# 0       90
# 6       91
# 7      125
# 9      104
# 12     127
# 13      91
# 16      67
# 18      94
# 22     161
# 23      61
# 24     166
# 26     147
# 27     103
# 28      97
# 29     106
# 30     111
# 35     110
# 36     105
# 38      96
# 41     124
# 42     116
# 43      98
# 44      91
# 45      23
# 46     115
# 48     122
# 51      99
# 52      99
# 53      88
# 54     100
# 56     102
# 57      93
# 58      96
# 59      95
# 60      85
# 61      97
# 62      95
# 63      83
# 64     103
# 68     113
# 71      13
# 73     182
# 75     106
# 77      48
# 78     145
# 79     145
# 80      93
# 81     106
# 84     147
# 86      87
# 88      96
# 90      95
# 91      92
# 93      91
# 94      90
# 96      97
# 101     80
# 103    117
# 105    128
# 107     90
# 112    119
# 113    110
# 114    143
# 115    119
# 116    114
# 117     94
# 118    106
# 119     99
# 122    118
# 126    115
# 127     95
# 128    115
# 129    108
# 130     63
# 131    117
# 133    121
# ...

# %%
#could add some more minutes to duration to factor in ad time/popcorn break for kids - but can't because string column right now
